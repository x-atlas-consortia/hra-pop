# %% [markdown]
# # A notebook to compile counts for the HRApop paper

# %% [markdown]
# # Import libraries

# %%
# %pip install pandas numpy requests 

import pandas as pd
import numpy as np
import requests
import io
from pprint import pprint
# Out:
# Requirement already satisfied: pandas in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (2.3.4)
# Requirement already satisfied: requests in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /Users/abueckle/Documents/GitHub/hra-pop/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Set global variables

# %%
hra_pop_version = "v1.1"
branch = 'v1.1'

# %% [markdown]
# # Load data

# %%
sankey = pd.read_csv(
    f"https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/sankey.csv")

sankey
# Out:
# /var/folders/x7/ttglg94d4g500ypbdkw3__nw0000gq/T/ipykernel_24216/507210814.py:1: DtypeWarning: Columns (1,3,9,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   sankey = pd.read_csv(
#       portal study_paper                                                doi  \
# 0        HCA         NaN                                                NaN
# 1       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 2       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 3       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 4        HRA         NaN                                                NaN
# ...      ...         ...                                                ...
# 49158  DISCO         NaN                                                NaN
# 49159  DISCO         NaN                                                NaN
# 49160  DISCO         NaN                                                NaN
# 49161   KPMP         NaN  https://www.nature.com/articles/s41467-023-389...
# 49162   KPMP         NaN  https://www.nature.com/articles/s41467-023-389...
#
#       lead_author  is_azimuth_reference donor_id donor_sex  donor_age  \
# 0             NaN                   NaN    TSP27    Female       56.0
# 1             NaN                   NaN   Donor1      Male        NaN
# 2             NaN                   NaN   Donor2      Male        NaN
# 3             NaN                   NaN   Donor3      Male        NaN
# 4             NaN                   NaN   Donor1    Female       38.0
# ...           ...                   ...      ...       ...        ...
# 49158         NaN                   NaN    Donor   Unknown        NaN
# 49159         NaN                   NaN    Donor   Unknown        NaN
# 49160         NaN                   NaN    Donor   Unknown        NaN
# 49161         NaN                   NaN   Donor1      Male        NaN
# 49162         NaN                   NaN   Donor2    Female        NaN
#
#        donor_development_stage donor_race  ...  \
# 0                          NaN        NaN  ...
# 1                          NaN        NaN  ...
# 2                          NaN        NaN  ...
# 3                          NaN        NaN  ...
# 4                          NaN        NaN  ...
# ...                        ...        ...  ...
# 49158                      NaN        NaN  ...
# 49159                      NaN        NaN  ...
# 49160                      NaN        NaN  ...
# 49161                      NaN        NaN  ...
# 49162                      NaN        NaN  ...
#
#                                        unique_dataset_id  \
# 0      hhttps://api.cellxgene.cziscience.com/dp/v1/co...
# 1      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 2      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 3      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 4      http://purl.org/ccf/1.5/omap-1#Donor1_TissueBl...
# ...                                                  ...
# 49158         https://www.immunesinglecell.com/sample/d1
# 49159         https://www.immunesinglecell.com/sample/d2
# 49160         https://www.immunesinglecell.com/sample/d3
# 49161  https://zenodo.org/records/7653239#Donor1_Tiss...
# 49162  https://zenodo.org/records/7653239#Donor2_Tiss...
#
#                                        link_to_h5ad_file  \
# 0      https://cellxgene.cziscience.com/e/a357414d-20...
# 1               http://dx.doi.org/10.1681/ASN.2016091027
# 2               http://dx.doi.org/10.1681/ASN.2016091027
# 3           http://dx.doi.org/10.1016/j.trsl.2017.07.006
# 4      https://hubmapconsortium.github.io/ccf-release...
# ...                                                  ...
# 49158         https://www.immunesinglecell.com/sample/d1
# 49159         https://www.immunesinglecell.com/sample/d2
# 49160         https://www.immunesinglecell.com/sample/d3
# 49161                 https://zenodo.org/records/7653239
# 49162                 https://zenodo.org/records/7653239
#
#       sc_transcriptomics_or_sc_proteomics cell_type_annotation_tool  omap_id  \
# 0                                     NaN                       NaN      NaN
# 1                                     NaN                       NaN      NaN
# 2                                     NaN                       NaN      NaN
# 3                                     NaN                       NaN      NaN
# 4                                     NaN                       NaN      NaN
# ...                                   ...                       ...      ...
# 49158                                 NaN                       NaN      NaN
# 49159                                 NaN                       NaN      NaN
# 49160                                 NaN                       NaN      NaN
# 49161                                 NaN                       NaN      NaN
# 49162                                 NaN                       NaN      NaN
#
#        number_of_cells_total  number_of_unique_cell_types  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# ...                      ...                          ...
# 49158                    NaN                          NaN
# 49159                    NaN                          NaN
# 49160                    NaN                          NaN
# 49161                    NaN                          NaN
# 49162                    NaN                          NaN
#
#       hubmap_dataset_publication_status is_rui_registered is_atlas_dataset
# 0                                   NaN              True            False
# 1                                   NaN              True            False
# 2                                   NaN              True            False
# 3                                   NaN              True            False
# 4                                   NaN              True            False
# ...                                 ...               ...              ...
# 49158                               NaN             False            False
# 49159                               NaN             False            False
# 49160                               NaN             False            False
# 49161                               NaN              True            False
# 49162                               NaN              True            False
#
# [49163 rows x 32 columns]

# %%
# unique cells
universe_sc_transcriptomics_cell_counts = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/universe-sc-transcriptomics-cell-counts.csv', index_col=False)
universe_sc_proteomics_cell_counts = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/universe-sc-proteomics-cell-counts.csv', index_col=False)
universe_sc_transcriptomics_cell_instance_counts = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/universe-sc-transcriptomics-cell-instance-counts.csv', index_col=False)

# %% [markdown]
# # Pre-processing steps

# %% [markdown]
# ## Simplify rows with multiple annotations for getting accurate counts

# %%
tool_replacement = "sc_transcriptomics with Cell Summary"

sankey['cell_type_annotation_tool'] = sankey['cell_type_annotation_tool'].replace({
    'azimuth': tool_replacement,
    'celltypist': tool_replacement,
    'popv': tool_replacement,
    np.nan: "No Cell Summary"
})

# %% [markdown]
# ## Manually fix missing cell type annotation values for SenNet atlas datasets

# %% [markdown]
# See GitHub issue: https://github.com/x-atlas-consortia/hra-pop/issues/91

# %%
# Define the indexing criteria
criteria = (sankey['portal'] == "SenNet") & (
    sankey['is_atlas_dataset'] == True)

# Apply the change to the SenNet atlas datasets (2 as of HRApop v0.10.2)
sankey.loc[criteria, 'cell_type_annotation_tool'] = tool_replacement

sankey = sankey.drop_duplicates()

# %% [markdown]
# # Get counts for HRApop paper

# %% [markdown]
# The following sections provide counts of datasets and other metrics for HRApop v0.10.2.

# %% [markdown]
# ## Report numbers for Highlights

# %%
# All datasets downloaded and retrieved from extraction sites
all_datasets = sankey['unique_dataset_id'].unique()

print(f"Number of UNIVERSE datasets: {len(all_datasets)}")
# Out:
# Number of UNIVERSE datasets: 34153

# %%
# All sc-proteomics
all_sc_proteomics = sankey[['dataset_id', 'cell_type_annotation_tool']
                           ].loc[sankey['cell_type_annotation_tool'] == "sc_proteomics"].drop_duplicates()

print(f"Number of sc-proteomics datasets: {len(all_sc_proteomics)}")
# Out:
# Number of sc-proteomics datasets: 112

# %%
print(
    f'Number of sc-transcriptomics datasets: {len(sankey[(sankey['is_atlas_dataset'] == True) & (sankey['cell_type_annotation_tool'] != 'sc_proteomics')].drop_duplicates(subset=['unique_dataset_id']))}')
# Out:
# Number of sc-transcriptomics datasets: 570

# %%
# All datasets with cell summary
sc_transcriptomics_with_cell_summary = sankey[['unique_dataset_id', 'cell_type_annotation_tool']].loc[
    sankey['cell_type_annotation_tool'] == tool_replacement]['unique_dataset_id'].drop_duplicates()

print(f"Number of sc-transcriptomics datasets with cell summary: {len(sc_transcriptomics_with_cell_summary)}")
# Out:
# Number of sc-transcriptomics datasets with cell summary: 7900

# %%
# Organs in HRApop Atlas
organs_in_hra_pop = sankey.loc[sankey['is_atlas_dataset']
                                == True]['organ_name'].unique()
print(
    f"Unique organs in HRApop Atlas: {len(organs_in_hra_pop)}")
# Out:
# Unique organs in HRApop Atlas: 23

# %%
# Organs (m/f) in HRApop Atlas
organs_in_hra_pop_sex = sankey.loc[sankey['is_atlas_dataset']
                               == True]['organ_name_glb_file'].unique()
print(
    f"Organs (m/f) in HRApop Atlas: {len(organs_in_hra_pop_sex)}")
# Out:
# Organs (m/f) in HRApop Atlas: 40

# %%
# Volume covered by HRApop tissue blocks
volume = sankey.loc[sankey['is_atlas_dataset']== True].drop_duplicates(subset=['unique_dataset_id'])['tissue_block_volume'].sum()
print(
    f"Volume covered by HRApop tissue blocks: {volume}")
# Out:
# Volume covered by HRApop tissue blocks: 12178067.66798545

# %% [markdown]
# ## Report numbers for Sankey/experimental data

# %%
# atlas datasets
atlas = sankey.loc[sankey['is_atlas_dataset'] == True]['unique_dataset_id'].unique()
print(f"Atlas datasets: {len(atlas)}\n")

# datasets with extraction site but without cell summary
no_cell_summary = sankey.loc[(sankey['is_rui_registered'] == True) & (
    sankey['cell_type_annotation_tool'] == "No Cell Summary")]['unique_dataset_id'].unique()
print(f"Datasets with extraction site but without cell summary: {
      len(no_cell_summary)}\n")

# datasets with cell summary but without extraction site
no_rui = sankey.loc[(sankey['is_rui_registered'] ==False) & (
    sankey['cell_type_annotation_tool'] != "No Cell Summary")]
print(f"Datasets with cell summary but without extraction site: {
      len(no_rui)}\n")

# datasets with cell summary 
cell_summary = sankey.loc[sankey['cell_type_annotation_tool'] != "No Cell Summary"]
print(f"Datasets with cell summary: {
      len(cell_summary)}\n")

# datasets with neither
non_atlas_without_either = sankey.loc[(sankey['cell_type_annotation_tool'] == "No Cell Summary") & (sankey['is_rui_registered'] == False)]
print(f"Datasets with neither: {len(non_atlas_without_either)}\n")

# non-atlas datasets total
non_atlas_total = sankey.loc[(
    sankey['is_atlas_dataset'] == False)]['unique_dataset_id'].unique()
print(f"Non-atlas datasets total: {len(non_atlas_total)}\n")

# unique cells
sc_transcriptomics_cell_counts = universe_sc_transcriptomics_cell_counts[
    'universe_sc_transcriptomics_cell_count'].iloc[0]
print(
    f'Unique cells from sc-transcriptomics datasets in the Universe: {sc_transcriptomics_cell_counts}\n')

sc_transcriptomics_cell_counts_preannotated = universe_sc_transcriptomics_cell_counts[
    'universe_sc_transcriptomics_preannotated_cell_count'].iloc[0]
print(
    f'Unique cells from sc-transcriptomics datasets in the Universe (preannotated): {sc_transcriptomics_cell_counts_preannotated}\n')

sc_proteomics_cell_counts = universe_sc_proteomics_cell_counts[
    'universe_sc_proteomics_cell_count'].iloc[0]
print(
    f'Unique cells from sc-proteomics datasets in the Universe: {sc_proteomics_cell_counts}\n')
# Out:
# Atlas datasets: 682
#
# Datasets with extraction site but without cell summary: 6719
#
# Datasets with cell summary but without extraction site: 18609
#
# Datasets with cell summary: 19788
#
# Datasets with neither: 16160
#
# Non-atlas datasets total: 33471
#
# Unique cells from sc-transcriptomics datasets in the Universe: 66241635
#
# Unique cells from sc-transcriptomics datasets in the Universe (preannotated): 71814459
#
# Unique cells from sc-proteomics datasets in the Universe: 35991932

# %%
# h5ad files
print(f'Unique h5ad files: {sankey['link_to_h5ad_file'].nunique()}')
# Out:
# Unique h5ad files: 23007

# %% [markdown]
# ## AS Counts

# %%
# Read the CSV data
df_as_data = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas-ad-hoc/cell-types-in-anatomical-structurescts-per-as.csv')

# Display the DataFrame
df_as_data
# Out:
#                  organ                                             as  \
# 0      large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 1      large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 2      large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 3      large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# 4      large intestine  http://purl.obolibrary.org/obo/UBERON_0001052
# ...                ...                                            ...
# 17893             lung            http://purl.org/sig/ont/fma/fma7508
# 17894             lung            http://purl.org/sig/ont/fma/fma7508
# 17895             lung            http://purl.org/sig/ont/fma/fma7508
# 17896             lung            http://purl.org/sig/ont/fma/fma7508
# 17897             lung            http://purl.org/sig/ont/fma/fma7508
#
#                                       as_label     sex           tool  \
# 0                                       rectum  Female     celltypist
# 1                                       rectum  Female     celltypist
# 2                                       rectum  Female     celltypist
# 3                                       rectum  Female     celltypist
# 4                                       rectum  Female     celltypist
# ...                                        ...     ...            ...
# 17893  Left posterior basal segmental bronchus    Male  sc_proteomics
# 17894  Left posterior basal segmental bronchus    Male  sc_proteomics
# 17895  Left posterior basal segmental bronchus    Male  sc_proteomics
# 17896  Left posterior basal segmental bronchus    Male  sc_proteomics
# 17897  Left posterior basal segmental bronchus    Male  sc_proteomics
#
#                  modality                                    cell_id  \
# 0      sc_transcriptomics  http://purl.obolibrary.org/obo/CL_1000347
# 1      sc_transcriptomics  http://purl.obolibrary.org/obo/CL_0000987
# 2      sc_transcriptomics  http://purl.obolibrary.org/obo/CL_4030026
# 3      sc_transcriptomics  http://purl.obolibrary.org/obo/CL_0000896
# 4      sc_transcriptomics  http://purl.obolibrary.org/obo/CL_0000798
# ...                   ...                                        ...
# 17893       sc_proteomics  http://purl.obolibrary.org/obo/CL_0000738
# 17894       sc_proteomics  http://purl.obolibrary.org/obo/CL_0000097
# 17895       sc_proteomics  http://purl.obolibrary.org/obo/CL_0000556
# 17896       sc_proteomics  http://purl.obolibrary.org/obo/CL_0000236
# 17897       sc_proteomics  http://purl.obolibrary.org/obo/CL_4033043
#
#                     cell_label  cell_count  cell_percentage  dataset_count
# 0                   Colonocyte       1.224         0.149982              3
# 1              IgA plasma cell       1.182         0.144835              3
# 2            BEST4+ epithelial       0.701         0.085896              3
# 3              Activated CD4 T       0.690         0.084548              3
# 4                    TRGV2 gdT       0.502         0.061512              3
# ...                        ...         ...              ...            ...
# 17893                leukocyte   12247.812         0.020667              1
# 17894                mast cell    7465.020         0.012597              1
# 17895            megakaryocyte    5572.620         0.009403              1
# 17896                   b cell     627.480         0.001059              1
# 17897  macrophage:interstitial     228.084         0.000385              1
#
# [17898 rows x 11 columns]

# %%
# unique AS
print(f'Number of unique AS IDs in HRApop {hra_pop_version}: {len(df_as_data['as_label'].unique())}')
# Out:
# Number of unique AS IDs in HRApop v1.1: 98

# %%
unique_as_by_sex = df_as_data[['as_label', 'sex']].drop_duplicates()
print(
    f'Number of unique AS in HRApop {hra_pop_version} separated by sex: {len(unique_as_by_sex)}')
# Out:
# Number of unique AS in HRApop v1.1 separated by sex: 144

# %%
print(f'Number of organs covered by sc-transcriptomics: {sankey[(sankey['is_atlas_dataset'] == True) & (sankey['cell_type_annotation_tool'] != 'sc_proteomics')]['organ_name'].nunique()}')
# Out:
# Number of organs covered by sc-transcriptomics: 23

# %%
print(f'Number of AS covered by sc-proteomics: {df_as_data[df_as_data['tool'] == 'sc_proteomics']['as_label'].nunique()}')
# Out:
# Number of AS covered by sc-proteomics: 28

# %% [markdown]
# ## Get counts for HRA 10th release

# %%
sankey.groupby(['organ_name', 'is_atlas_dataset'])[
    'unique_dataset_id'].nunique().reset_index()
# Out:
#                                    organ_name  is_atlas_dataset  \
# 0                                   Left knee             False
# 1                                   Left knee              True
# 2                                  Right knee             False
# 3                                  Right knee              True
# 4    Set of lactiferous glands in left breast              True
# 5   Set of lactiferous glands in right breast             False
# 6   Set of lactiferous glands in right breast              True
# 7                           blood vasculature             False
# 8                                       brain             False
# 9                                       brain              True
# 10                                      heart             False
# 11                                      heart              True
# 12                            large intestine             False
# 13                            large intestine              True
# 14                                   left eye             False
# 15                        left fallopian tube             False
# 16                                left kidney             False
# 17                                left kidney              True
# 18                                 left ovary             False
# 19                                 left ovary              True
# 20                                left ureter             False
# 21                                left ureter              True
# 22                                      liver             False
# 23                                      liver              True
# 24                   male reproductive system             False
# 25                   male reproductive system              True
# 26                      mesenteric lymph node             False
# 27                      mesenteric lymph node              True
# 28                                   pancreas             False
# 29                                   pancreas              True
# 30                                   placenta             False
# 31                         respiratory system             False
# 32                         respiratory system              True
# 33                                  right eye             False
# 34                       right fallopian tube             False
# 35                               right kidney             False
# 36                               right kidney              True
# 37                                right ovary             False
# 38                                right ovary              True
# 39                               right ureter             False
# 40                               right ureter              True
# 41                               skin of body             False
# 42                               skin of body              True
# 43                            small intestine             False
# 44                            small intestine              True
# 45                                     spleen             False
# 46                                     spleen              True
# 47                                     thymus             False
# 48                                     thymus              True
# 49                            urinary bladder             False
# 50                            urinary bladder              True
# 51                                     uterus             False
#
#     unique_dataset_id
# 0                  14
# 1                   2
# 2                  23
# 3                  11
# 4                   2
# 5                   4
# 6                   3
# 7                   2
# 8                  65
# 9                  18
# 10                437
# 11                111
# 12                438
# 13                104
# 14                 26
# 15                101
# 16               1059
# 17                 85
# 18                 48
# 19                 18
# 20                 21
# 21                 12
# 22                 76
# 23                  2
# 24                 18
# 25                  6
# 26                 99
# 27                  6
# 28                479
# 29                 10
# 30                510
# 31               1753
# 32                119
# 33                 17
# 34                 14
# 35                797
# 36                 33
# 37                  6
# 38                  9
# 39                  4
# 40                  3
# 41                 47
# 42                 17
# 43                455
# 44                 78
# 45                125
# 46                 15
# 47                 60
# 48                  4
# 49                 20
# 50                 14
# 51                  1

# %% [markdown]
# ## Crosswalks

# %%
crosswalk_azimuth = pd.read_csv(
    'https://cdn.humanatlas.io/digital-objects/ctann/azimuth/v1.2/assets/azimuth-crosswalk.csv', skiprows=10)
crosswalk_azimuth
# Out:
#      Organ_Level        Organ_ID                  Annotation_Label  \
# 0       Heart_L2  UBERON:0000948                         Adipocyte
# 1       Heart_L2  UBERON:0000948              Arterial Endothelial
# 2       Heart_L2  UBERON:0000948              Atrial Cardiomyocyte
# 3       Heart_L2  UBERON:0000948                                 B
# 4       Heart_L2  UBERON:0000948             Capillary Endothelial
# ..           ...             ...                               ...
# 759       Kidney  UBERON:0002113  Peritubular Capilary Endothelial
# 760  Bone_marrow  UBERON:0002371                    CD8 Effector_1
# 761  Bone_marrow  UBERON:0002371                    CD8 Effector_2
# 762  Bone_marrow  UBERON:0002371                    CD8 Effector_3
# 763  Bone_marrow  UBERON:0002371                   T Proliferating
#
#     Annotation_Label_ID                                    CL_Label  \
# 0            AZ:0000001                                   adipocyte
# 1            AZ:0000002                  endothelial cell of artery
# 2            AZ:0000003              regular atrial cardiac myocyte
# 3            AZ:0000004                                      B cell
# 4            AZ:0000005                  capillary endothelial cell
# ..                  ...                                         ...
# 759                 NaN      peritubular capillary endothelial cell
# 760                 NaN  effector CD8-positive, alpha-beta T cell:1
# 761                 NaN  effector CD8-positive, alpha-beta T cell:2
# 762                 NaN  effector CD8-positive, alpha-beta T cell:3
# 763                 NaN                              cycling T cell
#
#           CL_ID          CL_Match
# 0    CL:0000136   skos:exactMatch
# 1    CL:1000413   skos:exactMatch
# 2    CL:0002129   skos:exactMatch
# 3    CL:0000236   skos:exactMatch
# 4    CL:0002144   skos:exactMatch
# ..          ...               ...
# 759  CL:1001033   skos:exactMatch
# 760  CL:0001050  skos:narrowMatch
# 761  CL:0001050  skos:narrowMatch
# 762  CL:0001050  skos:narrowMatch
# 763  CL:4033069   skos:exactMatch
#
# [764 rows x 7 columns]

# %%
crosswalk_celltypist = pd.read_csv(
    'https://cdn.humanatlas.io/digital-objects/ctann/celltypist/v1.1/assets/celltypist-crosswalk.csv', skiprows=10)
crosswalk_celltypist
# Out:
#          Organ_Level        Organ_ID            Annotation_Label  \
# 0           blood_L1  UBERON:0000178      Age-associated B cells
# 1           blood_L1  UBERON:0000178  C1 non-classical monocytes
# 2           blood_L1  UBERON:0000178              CD16+ NK cells
# 3           blood_L1  UBERON:0000178              CD16- NK cells
# 4           blood_L1  UBERON:0000178         Classical monocytes
# ..               ...             ...                         ...
# 888  Small_Intestine  UBERON:0002108               myofibroblast
# 889  Small_Intestine  UBERON:0002108      myofibroblast (RSPO2+)
# 890  Small_Intestine  UBERON:0002108                         pDC
# 891  Small_Intestine  UBERON:0002108            venous capillary
# 892  Small_Intestine  UBERON:0002108         �� cells (INS+)
#
#     Annotation_Label_ID                                           CL_Label  \
# 0            CT:0000001                              B cell:age-associated
# 1            CT:0000002                          non-classical monocyte:C1
# 2            CT:0000003  CD16-positive, CD56-dim natural killer cell, h...
# 3            CT:0000004  CD16-negative, CD56-bright natural killer cell...
# 4            CT:0000005                                 classical monocyte
# ..                  ...                                                ...
# 888                 NaN                                 myofibroblast cell
# 889                 NaN                          myofibroblast cell:RSPO2+
# 890                 NaN                        plasmacytoid dendritic cell
# 891                 NaN                          pre-venule capillary cell
# 892                 NaN                                          cell:INS+
#
#           CL_ID          CL_Match
# 0    CL:0000236  skos:narrowMatch
# 1    CL:0000875  skos:narrowMatch
# 2    CL:0000939   skos:exactMatch
# 3    CL:0000938   skos:exactMatch
# 4    CL:0000860   skos:exactMatch
# ..          ...               ...
# 888  CL:0000186   skos:exactMatch
# 889  CL:0000186  skos:narrowMatch
# 890  CL:0000784   skos:exactMatch
# 891  CL:4047030   skos:exactMatch
# 892  CL:0000000  skos:narrowMatch
#
# [893 rows x 7 columns]

# %%
crosswalk_popv = pd.read_csv(
    'https://cdn.humanatlas.io/digital-objects/ctann/popv/v1.2/assets/popv-crosswalk.csv', skiprows=10)
crosswalk_popv
# Out:
#                Organ_Level        Organ_ID  \
# 0                    blood  UBERON:0000178
# 1                    blood  UBERON:0000178
# 2                    blood  UBERON:0000178
# 3                    blood  UBERON:0000178
# 4                    blood  UBERON:0000178
# ..                     ...             ...
# 442         prostate gland  UBERON:0002367
# 443                 thymus  UBERON:0002370
# 444                 thymus  UBERON:0002370
# 445            bone marrow  UBERON:0002371
# 446  mesenteric lymph node  UBERON:0002509
#
#                                       Annotation_Label Annotation_Label_ID  \
# 0                CD141-positive myeloid dendritic cell          PV:0000001
# 1               CD4-positive, alpha-beta memory T cell          PV:0000002
# 2                      CD8-positive, alpha-beta T cell          PV:0000003
# 3    CD8-positive, alpha-beta cytokine secreting ef...          PV:0000004
# 4                                               T cell          PV:0000005
# ..                                                 ...                 ...
# 442                          bronchial epithelial cell                 NaN
# 443  CD4-positive, CD25-positive, alpha-beta regula...                 NaN
# 444                    CD4-positive, alpha-beta T cell                 NaN
# 445                              B cell, CD19-positive                 NaN
# 446                    CD4-positive, alpha-beta T cell                 NaN
#
#                                               CL_Label       CL_ID  \
# 0                CD141-positive myeloid dendritic cell  CL:0002394
# 1               CD4-positive, alpha-beta memory T cell  CL:0000897
# 2                      CD8-positive, alpha-beta T cell  CL:0000625
# 3    CD8-positive, alpha-beta cytokine secreting ef...  CL:0000908
# 4                                               T cell  CL:0000084
# ..                                                 ...         ...
# 442                                    epithelial cell  CL:0000066
# 443  CD4-positive, CD25-positive, alpha-beta regula...  CL:0000792
# 444                    CD4-positive, alpha-beta T cell  CL:0000624
# 445                              B cell, CD19-positive  CL:0001201
# 446                    CD4-positive, alpha-beta T cell  CL:0000624
#
#              CL_Match
# 0     skos:exactMatch
# 1     skos:exactMatch
# 2     skos:exactMatch
# 3     skos:exactMatch
# 4     skos:exactMatch
# ..                ...
# 442  skos:narrowMatch
# 443   skos:exactMatch
# 444   skos:exactMatch
# 445   skos:exactMatch
# 446   skos:exactMatch
#
# [447 rows x 7 columns]

# %%
crosswalk_vccf = pd.read_csv(
    'https://cdn.humanatlas.io/digital-objects/ctann/vccf/v1.0/assets/vccf-crosswalk.csv', skiprows=10)
crosswalk_vccf
# Out:
#                   Organ_Level        Organ_ID Annotation_Label_ID  \
# 0    bonemarrow-codex-chop_L1  UBERON:0002371        VCCF:0000001
# 1    bonemarrow-codex-chop_L1  UBERON:0002371        VCCF:0000002
# 2    bonemarrow-codex-chop_L1  UBERON:0002371        VCCF:0000003
# 3    bonemarrow-codex-chop_L1  UBERON:0002371        VCCF:0000004
# 4    bonemarrow-codex-chop_L1  UBERON:0002371        VCCF:0000005
# ..                        ...             ...                 ...
# 497  tonsil-codex-stanford_L3  UBERON:0002372        VCCF:0000498
# 498  tonsil-codex-stanford_L3  UBERON:0002372        VCCF:0000499
# 499  tonsil-codex-stanford_L3  UBERON:0002372        VCCF:0000500
# 500                       NaN             NaN        VCCF:0000501
# 501                       NaN             NaN        VCCF:0000502
#
#                       Annotation_Label                           CL_Label  \
# 0                     mesenchymal cell                   mesenchymal cell
# 1                         unknown cell                       cell:unknown
# 2                          immune cell                          leukocyte
# 3         hematopoeitic precursor cell       hematopoietic precursor cell
# 4                     endothelial cell                   endothelial cell
# ..                                 ...                                ...
# 497           squamous epithelial cell           squamous epithelial cell
# 498                       stromal cell                       stromal cell
# 499                             t cell                             T cell
# 500                   endothelial cell                   endothelial cell
# 501  endothelial cell of vascular tree  endothelial cell of vascular tree
#
#           CL_ID          CL_Match
# 0    CL:0008019   skos:exactMatch
# 1    CL:0000000  skos:narrowMatch
# 2    CL:0000738   skos:exactMatch
# 3    CL:0008001   skos:exactMatch
# 4    CL:0000115   skos:exactMatch
# ..          ...               ...
# 497  CL:0000076   skos:exactMatch
# 498  CL:0000499   skos:exactMatch
# 499  CL:0000084   skos:exactMatch
# 500  CL:0000115   skos:exactMatch
# 501  CL:0002139   skos:exactMatch
#
# [502 rows x 7 columns]

# %%
# extract CL IDs and labels with tool
extract = ['Organ_ID','Annotation_Label','Annotation_Label_ID','CL_ID', 'CL_Label', 'CL_Match']

# Extract the columns from each DataFrame
az_selected = crosswalk_azimuth[extract].assign(tool='azimuth')
ct_selected = crosswalk_celltypist[extract].assign(tool='celltypist')
popv_selected = crosswalk_popv[extract].assign(tool='popv')
vccf_selected = crosswalk_vccf[extract].assign(tool='vccf')

# Concatenate them into one DataFrame
df_crosswalks_combined = pd.concat(
    [az_selected, ct_selected, popv_selected, vccf_selected], ignore_index=True)

df_crosswalks_combined
# Out:
#             Organ_ID                   Annotation_Label Annotation_Label_ID  \
# 0     UBERON:0000948                          Adipocyte          AZ:0000001
# 1     UBERON:0000948               Arterial Endothelial          AZ:0000002
# 2     UBERON:0000948               Atrial Cardiomyocyte          AZ:0000003
# 3     UBERON:0000948                                  B          AZ:0000004
# 4     UBERON:0000948              Capillary Endothelial          AZ:0000005
# ...              ...                                ...                 ...
# 2601  UBERON:0002372           squamous epithelial cell        VCCF:0000498
# 2602  UBERON:0002372                       stromal cell        VCCF:0000499
# 2603  UBERON:0002372                             t cell        VCCF:0000500
# 2604             NaN                   endothelial cell        VCCF:0000501
# 2605             NaN  endothelial cell of vascular tree        VCCF:0000502
#
#            CL_ID                           CL_Label         CL_Match     tool
# 0     CL:0000136                          adipocyte  skos:exactMatch  azimuth
# 1     CL:1000413         endothelial cell of artery  skos:exactMatch  azimuth
# 2     CL:0002129     regular atrial cardiac myocyte  skos:exactMatch  azimuth
# 3     CL:0000236                             B cell  skos:exactMatch  azimuth
# 4     CL:0002144         capillary endothelial cell  skos:exactMatch  azimuth
# ...          ...                                ...              ...      ...
# 2601  CL:0000076           squamous epithelial cell  skos:exactMatch     vccf
# 2602  CL:0000499                       stromal cell  skos:exactMatch     vccf
# 2603  CL:0000084                             T cell  skos:exactMatch     vccf
# 2604  CL:0000115                   endothelial cell  skos:exactMatch     vccf
# 2605  CL:0002139  endothelial cell of vascular tree  skos:exactMatch     vccf
#
# [2606 rows x 7 columns]

# %%
# get counts
print(f'Unique values across all crosswalks: {df_crosswalks_combined.nunique()}')
# Out:
# Unique values across all crosswalks: Organ_ID                 36
# Annotation_Label       1288
# Annotation_Label_ID    2214
# CL_ID                   495
# CL_Label                885
# CL_Match                  2
# tool                      4
# dtype: int64

# %%
# types of matches
df_crosswalks_combined.groupby('CL_Match').size()
# Out:
# CL_Match
# skos:exactMatch     1923
# skos:narrowMatch     683
# dtype: int64

# %%
df_crosswalks_combined.drop_duplicates(subset=['Annotation_Label_ID','CL_ID', 'tool'])
# Out:
#             Organ_ID                   Annotation_Label Annotation_Label_ID  \
# 0     UBERON:0000948                          Adipocyte          AZ:0000001
# 1     UBERON:0000948               Arterial Endothelial          AZ:0000002
# 2     UBERON:0000948               Atrial Cardiomyocyte          AZ:0000003
# 3     UBERON:0000948                                  B          AZ:0000004
# 4     UBERON:0000948              Capillary Endothelial          AZ:0000005
# ...              ...                                ...                 ...
# 2601  UBERON:0002372           squamous epithelial cell        VCCF:0000498
# 2602  UBERON:0002372                       stromal cell        VCCF:0000499
# 2603  UBERON:0002372                             t cell        VCCF:0000500
# 2604             NaN                   endothelial cell        VCCF:0000501
# 2605             NaN  endothelial cell of vascular tree        VCCF:0000502
#
#            CL_ID                           CL_Label         CL_Match     tool
# 0     CL:0000136                          adipocyte  skos:exactMatch  azimuth
# 1     CL:1000413         endothelial cell of artery  skos:exactMatch  azimuth
# 2     CL:0002129     regular atrial cardiac myocyte  skos:exactMatch  azimuth
# 3     CL:0000236                             B cell  skos:exactMatch  azimuth
# 4     CL:0002144         capillary endothelial cell  skos:exactMatch  azimuth
# ...          ...                                ...              ...      ...
# 2601  CL:0000076           squamous epithelial cell  skos:exactMatch     vccf
# 2602  CL:0000499                       stromal cell  skos:exactMatch     vccf
# 2603  CL:0000084                             T cell  skos:exactMatch     vccf
# 2604  CL:0000115                   endothelial cell  skos:exactMatch     vccf
# 2605  CL:0002139  endothelial cell of vascular tree  skos:exactMatch     vccf
#
# [2388 rows x 7 columns]

# %%
print(f'Number unique crosswalking operations: {len(df_crosswalks_combined)}')
# Out:
# Number unique crosswalking operations: 2606

# %%
# not crosswalked
df_not_crosswalked = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas-ad-hoc/unmapped-cell-ids.csv')
df_not_crosswalked
# Out:
# Empty DataFrame
# Columns: [tool, organ, cell_label, dataset_count]
# Index: []

# %%
print(
    f'Number of cell labels from CTann tools and sc-proteomics data that were not crosswalked: {df_not_crosswalked['cell_label'].nunique()}')
# Out:
# Number of cell labels from CTann tools and sc-proteomics data that were not crosswalked: 0

# %%
# number of cell IDs aggregated tp higher levels
df_level_1_2 = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas-ad-hoc/cell-types-level-mapping.csv')
df_level_1_2
# Out:
#                                   cell_label  \
# 0                                       cell
# 1                                     oocyte
# 2                                  stem cell
# 3                    hematopoietic stem cell
# 4    megakaryocyte-erythroid progenitor cell
# ..                                       ...
# 275                       cycling macrophage
# 276              cycling alveolar macrophage
# 277            cycling mononuclear phagocyte
# 278                     cycling myeloid cell
# 279           transit amplifying cell of gut
#
#                                        cell_id  \
# 0    http://purl.obolibrary.org/obo/CL_0000000
# 1    http://purl.obolibrary.org/obo/CL_0000023
# 2    http://purl.obolibrary.org/obo/CL_0000034
# 3    http://purl.obolibrary.org/obo/CL_0000037
# 4    http://purl.obolibrary.org/obo/CL_0000050
# ..                                         ...
# 275  http://purl.obolibrary.org/obo/CL_4033076
# 276  http://purl.obolibrary.org/obo/CL_4033077
# 277  http://purl.obolibrary.org/obo/CL_4033078
# 278  http://purl.obolibrary.org/obo/CL_4033081
# 279  http://purl.obolibrary.org/obo/CL_4047017
#
#                                level_1_cell_id     level_1_cell_label  \
# 0    http://purl.obolibrary.org/obo/CL_0000000  no mapped parent cell
# 1    http://purl.obolibrary.org/obo/CL_0000039         germ line cell
# 2    http://purl.obolibrary.org/obo/CL_0000034              stem cell
# 3    http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 4    http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# ..                                         ...                    ...
# 275  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 276  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 277  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 278  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 279  http://purl.obolibrary.org/obo/CL_0000066        epithelial cell
#
#                                level_2_cell_id     level_2_cell_label
# 0    http://purl.obolibrary.org/obo/CL_0000000  no mapped parent cell
# 1    http://purl.obolibrary.org/obo/CL_0000039         germ line cell
# 2    http://purl.obolibrary.org/obo/CL_0000034              stem cell
# 3    http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 4    http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# ..                                         ...                    ...
# 275  http://purl.obolibrary.org/obo/CL_0000235             macrophage
# 276  http://purl.obolibrary.org/obo/CL_0000235             macrophage
# 277  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 278  http://purl.obolibrary.org/obo/CL_0000988     hematopoietic cell
# 279  http://purl.obolibrary.org/obo/CL_0000066        epithelial cell
#
# [280 rows x 6 columns]

# %%
print(
    f'Number of unique  cell IDs aggregated to higher levels: {df_level_1_2['cell_label'].nunique()}')
print(
    f'Number of unique cell IDs in level 1: {df_level_1_2['level_1_cell_label'].nunique()}')
print(
    f'Number of unique cell IDs in level 2: {df_level_1_2['level_2_cell_label'].nunique()}')
# Out:
# Number of unique  cell IDs aggregated to higher levels: 280
# Number of unique cell IDs in level 1: 10
# Number of unique cell IDs in level 2: 20

# %%
# CTs per organ per tool from crosswalks. Alt source: https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/105da2e49b1b10d6531fb0fc302bd4cbb3c197eb/output-data/v1.0/reports/hra/ct-per-organ-per-tool.csv

# %%
# from crosswalks
df_crosswalks_combined.groupby(['tool','CL_ID']).size()
# Out:
# tool     CL_ID
# azimuth  AZ:0000557    1
#          AZ:0000560    1
#          AZ:0000568    1
#          AZ:0000569    1
#          AZ:0000570    1
#                       ..
# vccf     CL:4033054    1
#          CL:4033068    1
#          CL:4033092    1
#          CL:4047054    1
#          CL:4052009    4
# Length: 814, dtype: int64

# %%
df_crosswalks_combined
# Out:
#             Organ_ID                   Annotation_Label Annotation_Label_ID  \
# 0     UBERON:0000948                          Adipocyte          AZ:0000001
# 1     UBERON:0000948               Arterial Endothelial          AZ:0000002
# 2     UBERON:0000948               Atrial Cardiomyocyte          AZ:0000003
# 3     UBERON:0000948                                  B          AZ:0000004
# 4     UBERON:0000948              Capillary Endothelial          AZ:0000005
# ...              ...                                ...                 ...
# 2601  UBERON:0002372           squamous epithelial cell        VCCF:0000498
# 2602  UBERON:0002372                       stromal cell        VCCF:0000499
# 2603  UBERON:0002372                             t cell        VCCF:0000500
# 2604             NaN                   endothelial cell        VCCF:0000501
# 2605             NaN  endothelial cell of vascular tree        VCCF:0000502
#
#            CL_ID                           CL_Label         CL_Match     tool
# 0     CL:0000136                          adipocyte  skos:exactMatch  azimuth
# 1     CL:1000413         endothelial cell of artery  skos:exactMatch  azimuth
# 2     CL:0002129     regular atrial cardiac myocyte  skos:exactMatch  azimuth
# 3     CL:0000236                             B cell  skos:exactMatch  azimuth
# 4     CL:0002144         capillary endothelial cell  skos:exactMatch  azimuth
# ...          ...                                ...              ...      ...
# 2601  CL:0000076           squamous epithelial cell  skos:exactMatch     vccf
# 2602  CL:0000499                       stromal cell  skos:exactMatch     vccf
# 2603  CL:0000084                             T cell  skos:exactMatch     vccf
# 2604  CL:0000115                   endothelial cell  skos:exactMatch     vccf
# 2605  CL:0002139  endothelial cell of vascular tree  skos:exactMatch     vccf
#
# [2606 rows x 7 columns]

# %%
tally = (
    df_crosswalks_combined.groupby(['Organ_ID', 'tool'])['CL_Label']
    .nunique()
    .unstack(fill_value=0)
    .reset_index()
)

def try_get_organ_label(id:str):
  """_summary_

  Args:
      id (str): _description_
  """
  
  # Taken from https://github.com/hubmapconsortium/hra-workflows-runner/blob/main/src%2Fgtex%2Fdownloader.js#L24-L39
  ORGAN_MAPPING = {
      "bladder": "UBERON:0001255",
      "blood": "UBERON:0000178",
      "bone_marrow": "UBERON:0002371",
      "eye": "UBERON:0000970",
      "heart": "UBERON:0000948",
      "large_intestine": "UBERON:0000059",
      "liver": "UBERON:0002107",
      "lung": "UBERON:0002048",
      # or mesenteric lymph node (UBERON:0002509)?
      "lymph_node": "UBERON:0000029",
      "mammary": "UBERON:0001911",
      "pancreas": "UBERON:0001264",
      "prostate": "UBERON:0002367",
      "skin": "UBERON:0002097",
      "small_intestine": "UBERON:0002108",
      "spleen": "UBERON:0002106",
      "thymus": "UBERON:0002370",
      "trachea": "UBERON:0003126",
      "uterus": "UBERON:0000995",
      "vasculature": "UBERON:0004537",
      "breast": "UBERON:0001911",
      "esophagus mucosa": "UBERON:0002469",
      "esophagus muscularis": "UBERON:0004648",
      "skeletal muscle": "UBERON:0001134",
  }
  
  try:
    value_to_find = id
    keys = [k for k, v in ORGAN_MAPPING.items() if v == value_to_find]
   # Output: ['a', 'c']
    return keys
  except:
    return ""
  

tally['Organ_Label'] = tally['Organ_ID'].apply(lambda id: try_get_organ_label(id))
tally
# Out:
# tool        Organ_ID  azimuth  celltypist  popv  vccf        Organ_Label
# 0     UBERON:0000006        0          12     0     0                 []
# 1     UBERON:0000029        0          30    22    36       [lymph_node]
# 2     UBERON:0000059        0         133    18     0  [large_intestine]
# 3     UBERON:0000079        0           0    13     0                 []
# 4     UBERON:0000160        0          43     0    34                 []
# 5     UBERON:0000167        0           0     0    37                 []
# 6     UBERON:0000178       77          27    20     0            [blood]
# 7     UBERON:0000948       25          91     5     0            [heart]
# 8     UBERON:0000970        0           0    30     0              [eye]
# 9     UBERON:0000995        0           0    13     0           [uterus]
# 10    UBERON:0001004        0           0    36     0                 []
# 11    UBERON:0001013       30           0    12     0                 []
# 12    UBERON:0001043        0           0     0    19                 []
# 13    UBERON:0001134        0          18     0     0  [skeletal muscle]
# 14    UBERON:0001255        0           0    15     0          [bladder]
# 15    UBERON:0001264       13          17    14     5         [pancreas]
# 16    UBERON:0001347       52           0     0     0                 []
# 17    UBERON:0001384       19           0     0     0                 []
# 18    UBERON:0001723        0           0    11     0                 []
# 19    UBERON:0001911        0           0    14     0  [mammary, breast]
# 20    UBERON:0002048      107          87    39    29             [lung]
# 21    UBERON:0002097        0          33    24    20             [skin]
# 22    UBERON:0002106        0          33    25    20           [spleen]
# 23    UBERON:0002107       26          37    12     0            [liver]
# 24    UBERON:0002108        0         133    17     0  [small_intestine]
# 25    UBERON:0002113       58          35     0     0                 []
# 26    UBERON:0002367        0           0    13     0         [prostate]
# 27    UBERON:0002370        0           0    23     0           [thymus]
# 28    UBERON:0002371       47          44    15    49      [bone_marrow]
# 29    UBERON:0002372        0           0     0    70                 []
# 30    UBERON:0002373      141           0     0     0                 []
# 31    UBERON:0002421        0          24     0     0                 []
# 32    UBERON:0002450        0           0     0    29                 []
# 33    UBERON:0002509        0           0    23     0                 []
# 34    UBERON:0003126        0           0    18     0          [trachea]
# 35    UBERON:0004537        0           0    14     0      [vasculature]

# %%
def get_uberon_label(uberon_id: str) -> str:
    """Fetch the label for a given UBERON ID using the OLS API."""
    base_url = "https://www.ebi.ac.uk/ols/api/ontologies/uberon/terms"
    iri = f"http://purl.obolibrary.org/obo/{uberon_id.replace(':', '_')}"

    response = requests.get(base_url, params={"iri": iri})
    print("Request URL:", response.url)

    if response.ok:
        data = response.json()
        terms = data.get("_embedded", {}).get("terms", [])
        if terms:
            return terms[0].get("label", "Label not found")
        else:
            return "Label not found in response"
    else:
        return f"Error: {response.status_code}"


# Example
label = get_uberon_label("UBERON:0002450")
print("Label:", label)
# Out:
# Request URL: https://www.ebi.ac.uk/ols4/api/ontologies/uberon/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0002450
# Label: decidua

# %% [markdown]
# # Random queries

# %%
# get ATLAS datasets with donors < 18
underage = sankey[(sankey['donor_age'] < 18) & (sankey['is_atlas_dataset'] == True)]
underage
# Out:
# Empty DataFrame
# Columns: [portal, study_paper, doi, lead_author, is_azimuth_reference, donor_id, donor_sex, donor_age, donor_development_stage, donor_race, donor_bmi, organ_name, organ_name_glb_file, tissue_block_id, tissue_block_volume, collisions_bb, collisions_mesh, list_of_colliding_anatomical_structures_bb, list_of_colliding_anatomical_structures_mesh, list_of_colliding_anatomical_structures_bb_ids, list_of_colliding_anatomical_structures_mesh_ids, dataset_id, unique_dataset_id, link_to_h5ad_file, sc_transcriptomics_or_sc_proteomics, cell_type_annotation_tool, omap_id, number_of_cells_total, number_of_unique_cell_types, hubmap_dataset_publication_status, is_rui_registered, is_atlas_dataset]
# Index: []
#
# [0 rows x 32 columns]

# %%
sankey
# Out:
#       portal study_paper                                                doi  \
# 0        HCA         NaN                                                NaN
# 1       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 2       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 3       KPMP         NaN           http://dx.doi.org/10.1681/ASN.2016091027
# 4        HRA         NaN                                                NaN
# ...      ...         ...                                                ...
# 49158  DISCO         NaN                                                NaN
# 49159  DISCO         NaN                                                NaN
# 49160  DISCO         NaN                                                NaN
# 49161   KPMP         NaN  https://www.nature.com/articles/s41467-023-389...
# 49162   KPMP         NaN  https://www.nature.com/articles/s41467-023-389...
#
#       lead_author  is_azimuth_reference donor_id donor_sex  donor_age  \
# 0             NaN                   NaN    TSP27    Female       56.0
# 1             NaN                   NaN   Donor1      Male        NaN
# 2             NaN                   NaN   Donor2      Male        NaN
# 3             NaN                   NaN   Donor3      Male        NaN
# 4             NaN                   NaN   Donor1    Female       38.0
# ...           ...                   ...      ...       ...        ...
# 49158         NaN                   NaN    Donor   Unknown        NaN
# 49159         NaN                   NaN    Donor   Unknown        NaN
# 49160         NaN                   NaN    Donor   Unknown        NaN
# 49161         NaN                   NaN   Donor1      Male        NaN
# 49162         NaN                   NaN   Donor2    Female        NaN
#
#        donor_development_stage donor_race  ...  \
# 0                          NaN        NaN  ...
# 1                          NaN        NaN  ...
# 2                          NaN        NaN  ...
# 3                          NaN        NaN  ...
# 4                          NaN        NaN  ...
# ...                        ...        ...  ...
# 49158                      NaN        NaN  ...
# 49159                      NaN        NaN  ...
# 49160                      NaN        NaN  ...
# 49161                      NaN        NaN  ...
# 49162                      NaN        NaN  ...
#
#                                        unique_dataset_id  \
# 0      hhttps://api.cellxgene.cziscience.com/dp/v1/co...
# 1      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 2      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 3      http://dx.doi.org/10.1681/ASN.2016091027#Donor...
# 4      http://purl.org/ccf/1.5/omap-1#Donor1_TissueBl...
# ...                                                  ...
# 49158         https://www.immunesinglecell.com/sample/d1
# 49159         https://www.immunesinglecell.com/sample/d2
# 49160         https://www.immunesinglecell.com/sample/d3
# 49161  https://zenodo.org/records/7653239#Donor1_Tiss...
# 49162  https://zenodo.org/records/7653239#Donor2_Tiss...
#
#                                        link_to_h5ad_file  \
# 0      https://cellxgene.cziscience.com/e/a357414d-20...
# 1               http://dx.doi.org/10.1681/ASN.2016091027
# 2               http://dx.doi.org/10.1681/ASN.2016091027
# 3           http://dx.doi.org/10.1016/j.trsl.2017.07.006
# 4      https://hubmapconsortium.github.io/ccf-release...
# ...                                                  ...
# 49158         https://www.immunesinglecell.com/sample/d1
# 49159         https://www.immunesinglecell.com/sample/d2
# 49160         https://www.immunesinglecell.com/sample/d3
# 49161                 https://zenodo.org/records/7653239
# 49162                 https://zenodo.org/records/7653239
#
#       sc_transcriptomics_or_sc_proteomics cell_type_annotation_tool  omap_id  \
# 0                                     NaN           No Cell Summary      NaN
# 1                                     NaN           No Cell Summary      NaN
# 2                                     NaN           No Cell Summary      NaN
# 3                                     NaN           No Cell Summary      NaN
# 4                                     NaN           No Cell Summary      NaN
# ...                                   ...                       ...      ...
# 49158                                 NaN           No Cell Summary      NaN
# 49159                                 NaN           No Cell Summary      NaN
# 49160                                 NaN           No Cell Summary      NaN
# 49161                                 NaN           No Cell Summary      NaN
# 49162                                 NaN           No Cell Summary      NaN
#
#        number_of_cells_total  number_of_unique_cell_types  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
# ...                      ...                          ...
# 49158                    NaN                          NaN
# 49159                    NaN                          NaN
# 49160                    NaN                          NaN
# 49161                    NaN                          NaN
# 49162                    NaN                          NaN
#
#       hubmap_dataset_publication_status is_rui_registered is_atlas_dataset
# 0                                   NaN              True            False
# 1                                   NaN              True            False
# 2                                   NaN              True            False
# 3                                   NaN              True            False
# 4                                   NaN              True            False
# ...                                 ...               ...              ...
# 49158                               NaN             False            False
# 49159                               NaN             False            False
# 49160                               NaN             False            False
# 49161                               NaN              True            False
# 49162                               NaN              True            False
#
# [42667 rows x 32 columns]

# %%
# dataset IDs for sc-proteomics
dois = sankey[sankey['cell_type_annotation_tool'] =='sc_proteomics']
dois['doi'].unique()
# Out:
# array(['https://doi.org/10.1016/j.cell.2022.12.028', nan,
#        'https://doi.org/10.1101/2023.10.05.560733',
#        'https://doi.org/10.1038/s42003-023-04991-z',
#        'https://doi.org/10.1038/s41586-023-05915-x'], dtype=object)

# %%
# numbers for 10th 2/3D Datasets: https://docs.google.com/spreadsheets/d/1xG4stdTZW37pmgX4kAMOnsqtjHv_tbiDbGET2Tcokuk/edit?gid=1213346061#gid=1213346061
print(f'Universe datasets for brain: ')

sankey[sankey['organ_name'].str.contains('brain', na=False)]

sankey[(sankey['organ_name'].str.contains('lymph', na=False)) & (sankey['is_atlas_dataset'] == False)]['unique_dataset_id'].nunique()
# Out:
# Universe datasets for brain:
# 99

# %%
# 16,293 datasets -- all human & healthy, all ages. For how many can we do US1/2 prediction?
df_us1 = pd.read_csv(f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas/application-a1.csv')

#US#2: most similar AS
df_us2_as = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas/application-a2p1.csv')

#US#2: most similar extraction site
df_us2_es = pd.read_csv(
    f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/atlas/application-a2p3.csv')

# %%
df_us1
# Out:
#                                                    sample  \
# 0       http://purl.org/ccf/1.5/omap-6#Donor1_TissueBl...
# 1       http://purl.org/ccf/1.5/omap-6#Donor1_TissueBl...
# 2       http://purl.org/ccf/1.5/omap-6#Donor1_TissueBl...
# 3       http://purl.org/ccf/1.5/omap-6#Donor1_TissueBl...
# 4       http://purl.org/ccf/1.5/omap-6#Donor1_TissueBl...
# ...                                                   ...
# 124168  https://zenodo.org/records/7653239#Donor2_Tiss...
# 124169  https://zenodo.org/records/7653239#Donor2_Tiss...
# 124170  https://zenodo.org/records/7653239#Donor2_Tiss...
# 124171  https://zenodo.org/records/7653239#Donor2_Tiss...
# 124172  https://zenodo.org/records/7653239#Donor2_Tiss...
#
#                                              rui_location        organ  \
# 0       http://purl.org/ccf/1.5/168abaaf-f115-4606-a65...     pancreas
# 1       http://purl.org/ccf/1.5/168abaaf-f115-4606-a65...     pancreas
# 2       http://purl.org/ccf/1.5/168abaaf-f115-4606-a65...     pancreas
# 3       http://purl.org/ccf/1.5/168abaaf-f115-4606-a65...     pancreas
# 4       http://purl.org/ccf/1.5/168abaaf-f115-4606-a65...     pancreas
# ...                                                   ...          ...
# 124168  http://purl.org/ccf/1.5/b392110d-05a0-477e-840...  left kidney
# 124169  http://purl.org/ccf/1.5/b392110d-05a0-477e-840...  left kidney
# 124170  http://purl.org/ccf/1.5/b392110d-05a0-477e-840...  left kidney
# 124171  http://purl.org/ccf/1.5/b392110d-05a0-477e-840...  left kidney
# 124172  http://purl.org/ccf/1.5/b392110d-05a0-477e-840...  left kidney
#
#                organId     sex               tool            modality  \
# 0       UBERON:0001264    Male            azimuth  sc_transcriptomics
# 1       UBERON:0001264    Male         celltypist  sc_transcriptomics
# 2       UBERON:0001264    Male               popv  sc_transcriptomics
# 3       UBERON:0001264    Male               popv  sc_transcriptomics
# 4       UBERON:0001264    Male         celltypist  sc_transcriptomics
# ...                ...     ...                ...                 ...
# 124168  UBERON:0004538  Female  pan-human-azimuth  sc_transcriptomics
# 124169  UBERON:0004538  Female  pan-human-azimuth  sc_transcriptomics
# 124170  UBERON:0004538  Female  pan-human-azimuth  sc_transcriptomics
# 124171  UBERON:0004538  Female  pan-human-azimuth  sc_transcriptomics
# 124172  UBERON:0004538  Female  pan-human-azimuth  sc_transcriptomics
#
#                                           cell_id                cell_label  \
# 0       http://purl.obolibrary.org/obo/CL_0000738                    immune
# 1       http://purl.obolibrary.org/obo/CL_0000173                     delta
# 2       http://purl.obolibrary.org/obo/CL_0000115          endothelial cell
# 3       http://purl.obolibrary.org/obo/CL_0000763              myeloid cell
# 4       http://purl.obolibrary.org/obo/CL_0000171            alpha_immature
# ...                                           ...                       ...
# 124168  http://purl.obolibrary.org/obo/CL_0008019  Mesenchymal stromal cell
# 124169  http://purl.obolibrary.org/obo/CL_0000669                  Pericyte
# 124170  http://purl.obolibrary.org/obo/CL_0000542         Cycling T/NK cell
# 124171  http://purl.obolibrary.org/obo/CL_0000583       Alveolar macrophage
# 124172  http://purl.obolibrary.org/obo/CL_0002394                      cDC1
#
#         cell_count  percentage_of_total
# 0         39.19350             0.375514
# 1         34.97835             0.335128
# 2         30.00891             0.287516
# 3         29.60958             0.283690
# 4         28.97361             0.277597
# ...            ...                  ...
# 124168     0.07044             0.000259
# 124169     0.03522             0.000129
# 124170     0.03522             0.000129
# 124171     0.03522             0.000129
# 124172     0.03522             0.000129
#
# [124173 rows x 11 columns]

# %%
df_us2_as
# Out:
#                                                  dataset  \
# 0      https://api.cellxgene.cziscience.com/dp/v1/col...
# 1      https://api.cellxgene.cziscience.com/dp/v1/col...
# 2      https://api.cellxgene.cziscience.com/dp/v1/col...
# 3      https://api.cellxgene.cziscience.com/dp/v1/col...
# 4      https://api.cellxgene.cziscience.com/dp/v1/col...
# ...                                                  ...
# 38826  https://api.cellxgene.cziscience.com/dp/v1/col...
# 38827  https://api.cellxgene.cziscience.com/dp/v1/col...
# 38828  https://api.cellxgene.cziscience.com/dp/v1/col...
# 38829  https://api.cellxgene.cziscience.com/dp/v1/col...
# 38830  https://api.cellxgene.cziscience.com/dp/v1/col...
#
#                                       reported_organ     sex  \
# 0      http://purl.obolibrary.org/obo/UBERON_0000059  Female
# 1      http://purl.obolibrary.org/obo/UBERON_0000059  Female
# 2      http://purl.obolibrary.org/obo/UBERON_0000059  Female
# 3      http://purl.obolibrary.org/obo/UBERON_0000059  Female
# 4      http://purl.obolibrary.org/obo/UBERON_0000059  Female
# ...                                              ...     ...
# 38826  http://purl.obolibrary.org/obo/UBERON_0002048    Male
# 38827  http://purl.obolibrary.org/obo/UBERON_0002048    Male
# 38828  http://purl.obolibrary.org/obo/UBERON_0002048    Male
# 38829  http://purl.obolibrary.org/obo/UBERON_0002048    Male
# 38830  http://purl.obolibrary.org/obo/UBERON_0002048    Male
#
#                     tool            modality  \
# 0             celltypist  sc_transcriptomics
# 1      pan-human-azimuth  sc_transcriptomics
# 2      pan-human-azimuth  sc_transcriptomics
# 3                   popv  sc_transcriptomics
# 4             celltypist  sc_transcriptomics
# ...                  ...                 ...
# 38826         celltypist  sc_transcriptomics
# 38827            azimuth  sc_transcriptomics
# 38828            azimuth  sc_transcriptomics
# 38829            azimuth  sc_transcriptomics
# 38830         celltypist  sc_transcriptomics
#
#                                                   as            as_tool  \
# 0      http://purl.obolibrary.org/obo/UBERON_0001052         celltypist
# 1      http://purl.obolibrary.org/obo/UBERON_0001052         celltypist
# 2      http://purl.obolibrary.org/obo/UBERON_0001052  pan-human-azimuth
# 3      http://purl.obolibrary.org/obo/UBERON_0001052               popv
# 4      http://purl.obolibrary.org/obo/UBERON_0001159         celltypist
# ...                                              ...                ...
# 38826            http://purl.org/sig/ont/fma/fma7505         celltypist
# 38827            http://purl.org/sig/ont/fma/fma7505         celltypist
# 38828            http://purl.org/sig/ont/fma/fma7505            azimuth
# 38829            http://purl.org/sig/ont/fma/fma7507            azimuth
# 38830            http://purl.org/sig/ont/fma/fma7507            azimuth
#
#        similarity
# 0        0.618886
# 1        0.441885
# 2        0.753950
# 3        0.796441
# 4        0.499888
# ...           ...
# 38826    0.814430
# 38827    0.834179
# 38828    0.790694
# 38829    0.757494
# 38830    0.576867
#
# [38831 rows x 8 columns]

# %%
df_us2_es
# Out:
#                                                  dataset  \
# 0      https://api.cellxgene.cziscience.com/dp/v1/col...
# 1      https://api.cellxgene.cziscience.com/dp/v1/col...
# 2      https://api.cellxgene.cziscience.com/dp/v1/col...
# 3      https://api.cellxgene.cziscience.com/dp/v1/col...
# 4      https://api.cellxgene.cziscience.com/dp/v1/col...
# ...                                                  ...
# 65860  https://api.cellxgene.cziscience.com/dp/v1/col...
# 65861  https://api.cellxgene.cziscience.com/dp/v1/col...
# 65862  https://doi.org/10.6084/m9.figshare.27921984#T...
# 65863  https://doi.org/10.6084/m9.figshare.27921984#T...
# 65864  https://doi.org/10.6084/m9.figshare.27921984#T...
#
#                                       reported_organ   sex               tool  \
# 0      http://purl.obolibrary.org/obo/UBERON_0000059  Male         celltypist
# 1      http://purl.obolibrary.org/obo/UBERON_0000059  Male               popv
# 2      http://purl.obolibrary.org/obo/UBERON_0000059  Male         celltypist
# 3      http://purl.obolibrary.org/obo/UBERON_0000059  Male               popv
# 4      http://purl.obolibrary.org/obo/UBERON_0000059  Male  pan-human-azimuth
# ...                                              ...   ...                ...
# 65860  http://purl.obolibrary.org/obo/UBERON_0000970  Male  pan-human-azimuth
# 65861  http://purl.obolibrary.org/obo/UBERON_0000970  Male  pan-human-azimuth
# 65862  http://purl.obolibrary.org/obo/UBERON_0002107  Male         celltypist
# 65863  http://purl.obolibrary.org/obo/UBERON_0002370  Male  pan-human-azimuth
# 65864  http://purl.obolibrary.org/obo/UBERON_0002370  Male  pan-human-azimuth
#
#                  modality                                           corridor  \
# 0      sc_transcriptomics  http://purl.org/ccf/1.5/09681d25-f08d-40ff-81c...
# 1      sc_transcriptomics  http://purl.org/ccf/1.5/09681d25-f08d-40ff-81c...
# 2      sc_transcriptomics  http://purl.org/ccf/1.5/2ae3cef9-6621-46da-b05...
# 3      sc_transcriptomics  http://purl.org/ccf/1.5/2ae3cef9-6621-46da-b05...
# 4      sc_transcriptomics  http://purl.org/ccf/1.5/27c90961-5430-4217-ad9...
# ...                   ...                                                ...
# 65860  sc_transcriptomics  http://purl.org/ccf/1.5/fcfcc65b-f91f-4447-a29...
# 65861  sc_transcriptomics  http://purl.org/ccf/1.5/ff034c0c-a625-48b8-891...
# 65862  sc_transcriptomics  http://purl.org/ccf/1.5/8c2283cd-667a-4fa1-902...
# 65863  sc_transcriptomics  http://purl.org/ccf/1.5/ca976270-c7b0-4ae4-b18...
# 65864  sc_transcriptomics  http://purl.org/ccf/1.5/c8ce1bee-a81d-4d16-bd9...
#
#            corridor_tool  similarity
# 0             celltypist    0.730745
# 1                   popv    0.978046
# 2             celltypist    0.463040
# 3                   popv    0.888965
# 4             celltypist    0.520698
# ...                  ...         ...
# 65860  pan-human-azimuth    0.733135
# 65861  pan-human-azimuth    0.733135
# 65862         celltypist    0.555271
# 65863               popv    0.371291
# 65864               popv    0.368466
#
# [65865 rows x 8 columns]

# %%
print(f'Unique extraction sites for which we predict US#1: {df_us1['rui_location'].nunique()}.')
# Out:
# Unique extraction sites for which we predict US#1: 767.

# %%
print(f'Unique datasets for US#2 (most similar AS): {df_us2_as['dataset'].nunique()}.')
# Out:
# Unique datasets for US#2 (most similar AS): 3630.

# %%
print(
    f'Unique datasets for US#2 (most similar extraction site/corridor): {df_us2_es['dataset'].nunique()}.')
# Out:
# Unique datasets for US#2 (most similar extraction site/corridor): 3344.

# %%
# How many are adult?
sankey[sankey['donor_age'] >= 18]['unique_dataset_id'].nunique()
# Out:
# 12146

# %% [markdown]
# ## Extraction sites

# %%
url = f'https://raw.githubusercontent.com/x-atlas-consortia/hra-pop/refs/heads/{branch}/output-data/{hra_pop_version}/reports/universe-ad-hoc/extraction-sites.csv'

universe_extraction_sites = pd.read_csv(url)
universe_extraction_sites
# Out:
#                                         extraction_site
# 0     http://purl.org/ccf/1.5/169974a5-31ad-412a-b04...
# 1     http://purl.org/ccf/1.5/16c0c184-90a0-47b5-8d2...
# 2     http://purl.org/ccf/1.5/170c16c9-b5c4-4466-a27...
# 3     http://purl.org/ccf/1.5/1715e3d6-1556-4c8e-b93...
# 4     http://purl.org/ccf/1.5/17257912-7925-4731-876...
# ...                                                 ...
# 1301  http://purl.org/ccf/1.5/c7265539-ebc3-4a1e-893...
# 1302  http://purl.org/ccf/1.5/c7627c70-e8ce-446e-939...
# 1303  http://purl.org/ccf/1.5/c7ed4142-ddad-4cf5-b83...
# 1304  http://purl.org/ccf/1.5/f2a0eb6b-7729-40ac-baa...
# 1305  http://purl.org/ccf/1.5/fc556dba-cfb0-490d-913...
#
# [1306 rows x 1 columns]

# %%
def get_etraction_site_and_mesh_collisions(iri:str):
  """Takes an IRI, gets the extraction site and mesh collisions

  Args:
      iri (str): IRI for the extraction site
  """
  # initialize result
  result = (set(), set())
  
  # loop through extraction site IDs and get extraction site data
  api_extraction_site_base = 'https://apps.humanatlas.io/api/v1/extraction-site?iri='
  api_collisions_base = 'https://apps.humanatlas.io/api/v1/collisions'
  
  try:
    response = requests.get(api_extraction_site_base+iri)
    if response.ok:
        print(f'Successfully got extraction site data for {iri}!')
        extraction_site = response.json()
        try:
          headers = {
              "accept": "application/json",
              "content-type": "application/json"
          }
          data = extraction_site
          response = requests.post(api_collisions_base, headers=headers, json=data)
          if response.ok:
              print(f'Successfully got mesh collisions for {extraction_site['@id']}!')
              mesh = response.json()
              mesh_iris = [collision['representation_of'] for collision in mesh]
              result[0].update(mesh_iris)
              
              organ_iris = [collision['organ'] for collision in mesh]
              result[1].update(organ_iris)
              
          else:
              print(f"Request failed with status code {response.status_code}")
        except requests.exceptions.RequestException as e:
          print(f"An error occurred: {e}")
    else: 
      print(f"Request failed with status code {response.status_code}")
  except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
    
  print(f"Returning {result}")
  print()
  return result

# %%
unique_iris = {
    'anatomical_structures': set(),
    'organs': set()
}

# Apply the function to each row
results = universe_extraction_sites['extraction_site'].apply(
    lambda iri: get_etraction_site_and_mesh_collisions(iri)
)

# Unpack the tuple of sets and update each unique set
for result in results:
    print(f'now working with {result}')
    if isinstance(result, tuple) and len(result) == 2:
        as_set, organ_set = result
        unique_iris['anatomical_structures'].update(as_set)
        unique_iris['organs'].update(organ_set)

# Print results
pprint(unique_iris)
# Out:
# Successfully got extraction site data for http://purl.org/ccf/1.5/169974a5-31ad-412a-b043-f7d3bb5851d9!
# Successfully got mesh collisions for http://purl.org/ccf/1.5
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0002079', 'http://purl.obolibrary.org/obo/UBERON_0002084', 'http://purl.obolibrary.org/obo/UBERON_0002078'}, {'heart-female'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0001069', 'http://purl.obolibrary.org/obo/UBERON_0010373'}, {'pancreas-female'})
# now working with (set(), set())
# now working with (set(), set())
# now working with ({'http://purl.org/sig/ont/fma/fma7360'}, {'lung-female'})
# now working with ({'http://purl.org/sig/ont/fma/fma14966'}, {'small-intestine-female'})
# now working with ({'http://purl.org/sig/ont/fma/fma15837'}, {'spleen-male'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0001310', 'http://purl.obolibrary.org/obo/UBERON_0002331', 'http://purl.obolibrary.org/obo/UBERON_0002066'}, {'placenta-full-term-female'})
# now working with ({'http://purl.org/sig/ont/fma/fma15828'}, {'spleen-female'})
# now working with ({'http://purl.org/sig/ont/fma/fma15828'}, {'spleen-female'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0002097'}, {'skin-male'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0002115'}, {'small-intestine-female'})
# now working with ({''}, {'placenta-full-term-female'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0004027'}, {'placenta-full-term-female'})
# now working with (set(), set())
# now working with ({'http://purl.org/sig/ont/fma/fma15828'}, {'spleen-female'})
# now working with (set(), set())
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0001153', 'http://purl.obolibrary.org/obo/UBERON_0001156'}, {'large-intestine-female'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0005457'}, {'thymus-female'})
# now working with ({'http://purl.obolibrary.org/obo/UBERON_0001156'}, {'large-intestine-male'})
# {'anatomical_structures': {'',
#                            'http://purl.obolibrary.org/obo/UBERON_0000305',
#                            'http://purl.obolibrary.org/obo/UBERON_0000569',
#                            'http://purl.obolibrary.org/obo/UBERON_0000998',
#                            'http://purl.obolibrary.org/obo/UBERON_0000999',
#                            'http://purl.obolibrary.org/obo/UBERON_0001052',
#                            'http://purl.obolibrary.org/obo/UBERON_0001069',
#                            'http://purl.obolibrary.org/obo/UBERON_0001150',
#                            'http://purl.obolibrary.org/obo/UBERON_0001151',
#                            'http://purl.obolibrary.org/obo/UBERON_0001153',
#                            'http://purl.obolibrary.org/obo/UBERON_0001156',
#                            'http://purl.obolibrary.org/obo/UBERON_0001157',
#                            'http://purl.obolibrary.org/obo/UBERON_0001158',
#                            'http://purl.obolibrary.org/obo/UBERON_0001159',
#                            'http://purl.obolibrary.org/obo/UBERON_0001222',
#                            'http://purl.obolibrary.org/obo/UBERON_0001223',
#                            'http://purl.obolibrary.org/obo/UBERON_0001228',
#                            'http://purl.obolibrary.org/obo/UBERON_0001248',
#                            'http://purl.obolibrary.org/obo/UBERON_0001257',
#                            'http://purl.obolibrary.org/obo/UBERON_0001284',
#                            'http://purl.obolibrary.org/obo/UBERON_0001310',
#                            'http://purl.obolibrary.org/obo/UBERON_0001626',
#                            'http://purl.obolibrary.org/obo/UBERON_0002007',
#                            'http://purl.obolibrary.org/obo/UBERON_0002015',
#                            'http://purl.obolibrary.org/obo/UBERON_0002066',
#                            'http://purl.obolibrary.org/obo/UBERON_0002078',
#                            'http://purl.obolibrary.org/obo/UBERON_0002079',
#                            'http://purl.org/sig/ont/fma/fma14966',
#                            'http://purl.org/sig/ont/fma/fma15729',
#                            'http://purl.org/sig/ont/fma/fma15828',
#                            'http://purl.org/sig/ont/fma/fma15837',
#                            'http://purl.org/sig/ont/fma/fma15839',
#                            'http://purl.org/sig/ont/fma/fma17561',
#                            'http://purl.org/sig/ont/fma/fma18489',
#                            'http://purl.org/sig/ont/fma/fma18490',
#                            'http://purl.org/sig/ont/fma/fma18491',
#                            'http://purl.org/sig/ont/fma/fma18492',
#                            'http://purl.org/sig/ont/fma/fma18493',
#                            'http://purl.org/sig/ont/fma/fma18497',
#                            'http://purl.org/sig/ont/fma/fma18498',
#                            'http://purl.org/sig/ont/fma/fma19719',
#                            'http://purl.org/sig/ont/fma/fma224876',
#                            'http://purl.org/sig/ont/fma/fma224878',
#                            'http://purl.org/sig/ont/fma/fma24477',
#                            'http://purl.org/sig/ont/fma/fma24478',
#                            'http://purl.org/sig/ont/fma/fma261236',
#                            'http://purl.org/sig/ont/fma/fma261238',
#                            'http://purl.org/sig/ont/fma/fma32860',
#                            'http://purl.org/sig/ont/fma/fma32862',
#                            'http://purl.org/sig/ont/fma/fma33189',
#                            'http://purl.org/sig/ont/fma/fma33190',
#                            'http://purl.org/sig/ont/fma/fma3860',
#                            'http://purl.org/sig/ont/fma/fma49152',
#                            'http://purl.org/sig/ont/fma/fma49153',
#                            'http://purl.org/sig/ont/fma/fma58271',
#                            'http://purl.org/sig/ont/fma/fma58272',
#                            'http://purl.org/sig/ont/fma/fma58296',
#                            'http://purl.org/sig/ont/fma/fma58297',
#                            'http://purl.org/sig/ont/fma/fma58299',
#                            'http://purl.org/sig/ont/fma/fma58300',
#                            'http://purl.org/sig/ont/fma/fma58302',
#                            'http://purl.org/sig/ont/fma/fma58303',
#                            'http://purl.org/sig/ont/fma/fma58601',
#                            'http://purl.org/sig/ont/fma/fma58602',
#                            'http://purl.org/sig/ont/fma/fma58635',
#                            'http://purl.org/sig/ont/fma/fma58636',
#                            'http://purl.org/sig/ont/fma/fma58638',
#                            'http://purl.org/sig/ont/fma/fma58639',
#                            'http://purl.org/sig/ont/fma/fma58661',
#                            'http://purl.org/sig/ont/fma/fma58663',
#                            'http://purl.org/sig/ont/fma/fma58839',
#                            'http://purl.org/sig/ont/fma/fma58840',
#                            'http://purl.org/sig/ont/fma/fma62659',
#                            'http://purl.org/sig/ont/fma/fma62662',
#                            'http://purl.org/sig/ont/fma/fma64019',
#                            'http://purl.org/sig/ont/fma/fma7206',
#                            'http://purl.org/sig/ont/fma/fma7262',
#                            'http://purl.org/sig/ont/fma/fma7264',
#                            'http://purl.org/sig/ont/fma/fma7265',
#                            'http://purl.org/sig/ont/fma/fma7267',
#                            'http://purl.org/sig/ont/fma/fma73119',
#                            'http://purl.org/sig/ont/fma/fma73165',
#                            'http://purl.org/sig/ont/fma/fma73166',
#                            'http://purl.org/sig/ont/fma/fma7338',
#                            'http://purl.org/sig/ont/fma/fma7339',
#                            'http://purl.org/sig/ont/fma/fma7359',
#                            'http://purl.org/sig/ont/fma/fma7360',
#                            'http://purl.org/sig/ont/fma/fma7361',
#                            'http://purl.org/sig/ont/fma/fma7362',
#                            'http://purl.org/sig/ont/fma/fma7363',
#                            'http://purl.org/sig/ont/fma/fma7364',
#                            'http://purl.org/sig/ont/fma/fma7365',
#                            'http://purl.org/sig/ont/fma/fma7366',
#                            'http://purl.org/sig/ont/fma/fma7373',
#                            'http://purl.org/sig/ont/fma/fma7374',
#                            'http://purl.org/sig/ont/fma/fma7375',
#                            'http://purl.org/sig/ont/fma/fma7377',
#                            'http://purl.org/sig/ont/fma/fma7378',
#                            'http://purl.org/sig/ont/fma/fma7379',
#                            'http://purl.org/sig/ont/fma/fma7385',
#                            'http://purl.org/sig/ont/fma/fma7386',
#                            'http://purl.org/sig/ont/fma/fma7398',
#                            'http://purl.org/sig/ont/fma/fma7399',
#                            'http://purl.org/sig/ont/fma/fma7400',
#                            'http://purl.org/sig/ont/fma/fma7402',
#                            'http://purl.org/sig/ont/fma/fma7403',
#                            'http://purl.org/sig/ont/fma/fma7416',
#                            'http://purl.org/sig/ont/fma/fma7419',
#                            'http://purl.org/sig/ont/fma/fma7420',
#                            'http://purl.org/sig/ont/fma/fma74238',
#                            'http://purl.org/sig/ont/fma/fma7426',
#                            'http://purl.org/sig/ont/fma/fma7428',
#                            'http://purl.org/sig/ont/fma/fma7430',
#                            'http://purl.org/sig/ont/fma/fma7505',
#                            'http://purl.org/sig/ont/fma/fma7507',
#                            'http://purl.org/sig/ont/fma/fma7508'},
#  'organs': {'blood-vasculature-female',
#             'blood-vasculature-male',
#             'brain-female',
#             'brain-male',
#             'eye-female-left',
#             'eye-female-right',
#             'eye-male-left',
#             'eye-male-right',
#             'fallopian-tube-female-left',
#             'fallopian-tube-female-right',
#             'heart-female',
#             'heart-male',
#             'kidney-female-left',
#             'kidney-female-right',
#             'kidney-male-left',
#             'kidney-male-right',
#             'knee-female-right',
#             'knee-male-left',
#             'knee-male-right',
#             'large-intestine-female',
#             'large-intestine-male',
#             'liver-female',
#             'liver-male',
#             'lung-female',
#             'lung-male',
#             'lymph-node-female',
#             'lymph-node-male',
#             'mammary-gland-female-left',
#             'mammary-gland-female-right',
#             'ovary-female-left',
#             'ovary-female-right',
#             'pancreas-female',
#             'pancreas-male',
#             'placenta-full-term-female',
#             'prostate-male',
#             'skin-male',
#             'small-intestine-female',
#             'small-intestine-male',
#             'spleen-female',
#             'spleen-male',
#             'thymus-female',
#             'thymus-male',
#             'ureter-female-left',
#             'ureter-female-right',
#             'ureter-male-left',
#             'ureter-male-right',
#             'urinary-bladder-female',
#             'urinary-bladder-male',
#             'uterus-female'}}

# %%
print(
    f'Number of AS covered across extraction sites in Universe: {len(unique_iris['anatomical_structures'])}')

print(
    f'Number of organs covered across extraction sites in Universe: {len(unique_iris['organs'])}')
# Out:
# Number of AS covered across extraction sites in Universe: 167
# Number of organs covered across extraction sites in Universe: 49
